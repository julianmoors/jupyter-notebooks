# %% [markdown]
# ## Profitable App Profiles for the Google Play Store
#
# Author: Julian Moors\
# Contact: julian.moors@outlook.com
#
# ### Introduction
# _The goal for this project is to analyse data to help developers understand what type of apps are likely to attract more users._

# %%
# code for Google Play Store
import pandas as pd
pd.set_option('display.max_rows', None)

google_df = pd.read_csv('data/google-playstore.csv')
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Data Cleaning

# %%
# user has reported incorrect data in row 10472
# google_df = google_df.drop(10472)

# drop duplicate app names
google_df = google_df.drop_duplicates(subset=['App'])

# drop all apps that are non-English
google_df = google_df[google_df['App'].str.contains(r'^[a-zA-Z\s]+$', na=False)]

# remove '+' and ',' characters from installs column
google_df['Installs'] = google_df['Installs'].str.replace('+', '').str.replace(',', '')

# show the top 20 free apps by number of installs
google_df[google_df['Type'] == 'Free'].sort_values(by='Installs', ascending=False).head(20)
# Out:
#                                 App             Category  Rating   Reviews  \
# 3473                        Dropbox         PRODUCTIVITY     4.4   1861310
# 5596                 Samsung Health   HEALTH_AND_FITNESS     4.3    480208
# 1722                 My Talking Tom                 GAME     4.5  14891223
# 3476                Google Calendar         PRODUCTIVITY     4.2    858208
# 3574                    Cloud Print         PRODUCTIVITY     4.1    282460
# 347   imo free video calls and chat        COMMUNICATION     4.3   4785892
# 342                 Viber Messenger        COMMUNICATION     4.3  11334799
# 2546                  Facebook Lite               SOCIAL     4.3   8606259
# 1662                            Pou                 GAME     4.3  10485308
# 2550                       Snapchat               SOCIAL     4.0  17014787
# 1655               Candy Crush Saga                 GAME     4.4  22426677
# 3235               Google Translate                TOOLS     4.4   5745093
# 3739                        Twitter   NEWS_AND_MAGAZINES     4.3  11667403
# 3450                 Microsoft Word         PRODUCTIVITY     4.5   2084126
# 3703                      MX Player        VIDEO_PLAYERS     4.5   6474426
# 3365                 ZenUI Launcher      PERSONALIZATION     4.7   1141545
# 4060                    Bad Piggies               FAMILY     4.3   1168959
# 4046         Geometry Dash Meltdown                 GAME     4.6   1591129
# 3428        Koi Free Live Wallpaper      PERSONALIZATION     4.2    290241
# 6068            Free GPS Navigation  MAPS_AND_NAVIGATION     4.2    618562
#
#                     Size   Installs  Type Price Content Rating  \
# 3473                 61M  500000000  Free     0       Everyone
# 5596                 70M  500000000  Free     0       Everyone
# 1722  Varies with device  500000000  Free     0       Everyone
# 3476  Varies with device  500000000  Free     0       Everyone
# 3574  Varies with device  500000000  Free     0       Everyone
# 347                  11M  500000000  Free     0       Everyone
# 342   Varies with device  500000000  Free     0       Everyone
# 2546  Varies with device  500000000  Free     0           Teen
# 1662                 24M  500000000  Free     0       Everyone
# 2550  Varies with device  500000000  Free     0           Teen
# 1655                 74M  500000000  Free     0       Everyone
# 3235  Varies with device  500000000  Free     0       Everyone
# 3739  Varies with device  500000000  Free     0     Mature 17+
# 3450  Varies with device  500000000  Free     0       Everyone
# 3703  Varies with device  500000000  Free     0       Everyone
# 3365                 15M   50000000  Free     0       Everyone
# 4060                 66M   50000000  Free     0       Everyone
# 4046                 48M   50000000  Free     0       Everyone
# 3428                4.1M   50000000  Free     0       Everyone
# 6068  Varies with device   50000000  Free     0       Everyone
#
#                        Genres       Last Updated         Current Ver  \
# 3473             Productivity     August 1, 2018  Varies with device
# 5596         Health & Fitness      July 31, 2018          5.17.2.009
# 1722                   Casual      July 19, 2018           4.8.0.132
# 3476             Productivity     August 6, 2018  Varies with device
# 3574             Productivity       May 23, 2018  Varies with device
# 347             Communication       June 8, 2018    9.8.000000010501
# 342             Communication      July 18, 2018  Varies with device
# 2546                   Social     August 1, 2018  Varies with device
# 1662                   Casual       May 25, 2018              1.4.77
# 2550                   Social      July 30, 2018  Varies with device
# 1655                   Casual       July 5, 2018           1.129.0.2
# 3235                    Tools     August 4, 2018  Varies with device
# 3739         News & Magazines     August 6, 2018  Varies with device
# 3450             Productivity      July 11, 2018    16.0.10325.20043
# 3703  Video Players & Editors     August 6, 2018  Varies with device
# 3365          Personalization      July 31, 2018  Varies with device
# 4060                   Puzzle        May 3, 2017               2.3.3
# 4046                   Arcade  December 22, 2017                1.01
# 3428          Personalization      June 24, 2014                 1.9
# 6068        Maps & Navigation       June 4, 2018  Varies with device
#
#              Android Ver
# 3473  Varies with device
# 5596          5.0 and up
# 1722          4.1 and up
# 3476  Varies with device
# 3574  Varies with device
# 347           4.0 and up
# 342   Varies with device
# 2546  Varies with device
# 1662          4.0 and up
# 2550  Varies with device
# 1655          4.1 and up
# 3235  Varies with device
# 3739  Varies with device
# 3450          4.4 and up
# 3703  Varies with device
# 3365  Varies with device
# 4060          4.1 and up
# 4046          4.0 and up
# 3428          2.1 and up
# 6068  Varies with device

# %% [markdown]
# ### Data Analysis

# %%
# from the top 1000 free apps by number of installs, show the top 20 genres
google_df[google_df['Type'] == 'Free'].sort_values(by='Installs', ascending=False).head(1000)['Genres'].value_counts()[:21]
# Out:
# Genres
# Tools                      72
# Entertainment              58
# Education                  42
# Lifestyle                  42
# Photography                41
# Health & Fitness           40
# Shopping                   40
# Productivity               39
# Dating                     39
# Social                     37
# Action                     36
# Business                   35
# Communication              34
# Casual                     34
# Medical                    31
# Finance                    29
# Personalization            28
# Sports                     28
# Books & Reference          24
# Video Players & Editors    20
# News & Magazines           18
# Name: count, dtype: int64
