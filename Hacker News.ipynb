# %% [markdown]
# ## Hacker News
#
# Author: Julian Moors\
# Contact: julian.moors@outlook.com
#
# ### Introduction
# _This project will analyse the title field of the Hacker News dataset and determine which posts have a larger engagement percentage._

# %% [markdown]
# ### Data Dictionary
#
# | Name     | Description             |
# | -------- | ----------------------- |
# | Column 0 | ID                      |
# | Column 1 | Title                   |
# | Column 2 | URL                     |
# | Column 3 | Votes (minus downvotes) |
# | Column 4 | Number of comments      |
# | Column 5 | Username                |
# | Column 6 | Timestamp               |

# %%
import pandas as pd

# load the dataset from the csv file
hn = pd.read_csv('data/hacker-news.csv')

# remove headers from dataset
headers = hn.columns
hn.columns = range(hn.shape[1])

# show first 5 rows
hn[:5]
# Out:
#           0                                                  1  \
# 0  12224879                          Interactive Dynamic Video
# 1  10975351  How to Use Open Source and Shut the Fuck Up at...
# 2  11964716  Florida DJs May Face Felony for April Fools' W...
# 3  11919867       Technology ventures: From Idea to Enterprise
# 4  10301696  Note by Note: The Making of Steinway L1037 (2007)
#
#                                                    2    3   4           5  \
# 0            http://www.interactivedynamicvideo.com/  386  52    ne0phyte
# 1  http://hueniverse.com/2016/01/26/how-to-use-op...   39  10      josep2
# 2  http://www.thewire.com/entertainment/2013/04/f...    2   1    vezycash
# 3  https://www.amazon.com/Technology-Ventures-Ent...    3   1     hswarna
# 4  http://www.nytimes.com/2007/11/07/movies/07ste...    8   2  walterbell
#
#                  6
# 0   8/4/2016 11:52
# 1  1/26/2016 19:30
# 2  6/23/2016 22:20
# 3   6/17/2016 0:01
# 4   9/30/2015 4:12

# %%
# select and display all posts that contain 'Ask HN:'
mask = hn.iloc[:, 1].str.contains('Ask HN:', case=False, na=False)
ask_posts = hn[mask]
ask_posts
# Out:
#               0                                                  1    2   3  \
# 7      12296411        Ask HN: How to improve my personal website?  NaN   2
# 17     10610020  Ask HN: Am I the only one outraged by Twitter ...  NaN  28
# 22     11610310  Ask HN: Aby recent changes to CSS that broke m...  NaN   1
# 30     12210105    Ask HN: Looking for Employee #3 How do I do it?  NaN   1
# 31     10394168  Ask HN: Someone offered to buy my browser exte...  NaN  28
# ...         ...                                                ...  ...  ..
# 20039  10994357  Ask HN: Is it feasible to port Apple's Swift t...  NaN   3
# 20042  12241954     Ask HN: What to do when a developer goes dark?  NaN   3
# 20045  12029526                         Ask HN: Killer app for AR?  NaN   2
# 20048  11227969  Ask HN: How do you balance a serious relations...  NaN  10
# 20061  11743946    Ask HN: Why are papers still published as PDFs?  NaN   4
#
#         4             5                 6
# 7       6  ahmedbaracat    8/16/2016 9:55
# 17     29          tkfx  11/22/2015 13:43
# 22      1     polskibus    5/2/2016 10:14
# 30      3        sph130    8/2/2016 14:20
# 31     17      roykolak  10/15/2015 16:38
# ...    ..           ...               ...
# 20039  17      schappim    1/29/2016 9:42
# 20042   3     bittysdad    8/7/2016 12:58
# 20045   2     davidiach     7/4/2016 8:50
# 20048   4        audace     3/5/2016 1:25
# 20061   2         adius    5/21/2016 9:22
#
# [1739 rows x 7 columns]

# %%
# select and display all posts that contain 'Show HN:'
mask = hn.iloc[:, 1].str.contains('Show HN:', case=False, na=False)
show_posts = hn[mask]
show_posts
# Out:
#               0                                                  1  \
# 13     10627194  Show HN: Wio Link  ESP8266 Based Web of Things...
# 39     10646440                Show HN: Something pointless I made
# 46     11590768  Show HN: Shanhu.io, a programming playground p...
# 84     12178806  Show HN: Webscope  Easy way for web developers...
# 97     10872799  Show HN: GeoScreenshot  Easily test Geo-IP bas...
# ...         ...                                                ...
# 19993  11222099  Show HN: Geocoding API built with government o...
# 19999  11735438  Show HN: Decorating: Animated pulsed for your ...
# 20014  10200913                           Show HN: Idea to startup
# 20065  11444393     Show HN: PhantomJsCloud, Headless Browser SaaS
# 20070  12149183  Show HN: Parse recipe ingredients using JavaSc...
#
#                                                   2    3    4               5  \
# 13                             https://iot.seeed.cc   26   22         kfihihc
# 39                          http://dn.ht/picklecat/  747  102         dhotson
# 46                                https://shanhu.io    1    1           h8liu
# 84                           http://webscopeapp.com    3    3       fastbrick
# 97                   https://www.geoscreenshot.com/    1    9      kpsychwave
# ...                                             ...  ...  ...             ...
# 19993                             https://latlon.io    6    6       evanmarks
# 19999        https://github.com/ryukinix/decorating    3    1           lerax
# 20014                     https://ideatostartup.org   14   17      nikhildaga
# 20065                    https://PhantomJsCloud.com    2    1        novaleaf
# 20070  https://github.com/herkyl/ingredients-parser    6    2  zongitsrinzler
#
#                       6
# 13     11/25/2015 14:03
# 39     11/29/2015 22:46
# 46      4/28/2016 18:05
# 84       7/28/2016 7:11
# 97       1/9/2016 20:45
# ...                 ...
# 19993     3/4/2016 4:50
# 19999    5/20/2016 3:48
# 20014   9/10/2015 22:17
# 20065     4/7/2016 3:04
# 20070   7/23/2016 11:35
#
# [1162 rows x 7 columns]

# %%
# select and display all posts that don't contain 'Ask HN:' or 'Show HN:'
mask = ~hn.iloc[:, 1].str.contains('Ask HN:', case=False, na=False) & \
       ~hn.iloc[:, 1].str.contains('Show HN:', case=False, na=False)
other_posts = hn[mask]
other_posts
# Out:
#               0                                                  1  \
# 0      12224879                          Interactive Dynamic Video
# 1      10975351  How to Use Open Source and Shut the Fuck Up at...
# 2      11964716  Florida DJs May Face Felony for April Fools' W...
# 3      11919867       Technology ventures: From Idea to Enterprise
# 4      10301696  Note by Note: The Making of Steinway L1037 (2007)
# ...         ...                                                ...
# 20095  12379592  How Purism Avoids Intels Active Management Tec...
# 20096  10339284          YC Application Translated and Broken Down
# 20097  10824382  Microkernels are slow and Elvis didn't do no d...
# 20098  10739875                      How Product Hunt really works
# 20099  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                        2    3    4  \
# 0                http://www.interactivedynamicvideo.com/  386   52
# 1      http://hueniverse.com/2016/01/26/how-to-use-op...   39   10
# 2      http://www.thewire.com/entertainment/2013/04/f...    2    1
# 3      https://www.amazon.com/Technology-Ventures-Ent...    3    1
# 4      http://www.nytimes.com/2007/11/07/movies/07ste...    8    2
# ...                                                  ...  ...  ...
# 20095  https://puri.sm/philosophy/how-purism-avoids-i...   10    6
# 20096  https://medium.com/@zreitano/the-yc-applicatio...    4    1
# 20097  http://blog.darknedgy.net/technology/2016/01/0...  169  132
# 20098  https://medium.com/@benjiwheeler/how-product-h...  695  222
# 20099              https://github.com/jmcarp/robobrowser  182   58
#
#                    5                 6
# 0           ne0phyte    8/4/2016 11:52
# 1             josep2   1/26/2016 19:30
# 2           vezycash   6/23/2016 22:20
# 3            hswarna    6/17/2016 0:01
# 4         walterbell    9/30/2015 4:12
# ...              ...               ...
# 20095  AdmiralAsshat    8/29/2016 2:22
# 20096       zreitano   10/6/2015 14:57
# 20097    vezzy-fnord     1/2/2016 0:49
# 20098          brw12  12/15/2015 19:32
# 20099      pmoriarty    5/12/2016 1:43
#
# [17199 rows x 7 columns]

# %%
# display the total number of comments from 'ask_posts'
num_ask = ask_posts.iloc[:,4].sum()
num_ask
# Out:
# np.int64(24450)

# %%
# display the total number of comments from 'show_posts'
num_show = show_posts.iloc[:,4].sum()
num_show
# Out:
# np.int64(11988)

# %%
# display the total number of comments from other posts
num_other = other_posts.iloc[:,4].sum()
num_other
# Out:
# np.int64(462088)

# %% [markdown]
# ### Data Analysis

# %%
# define total number of comments of all posts
num_total = num_ask + num_show + num_other

# %%
print("Ask Posts: {:.2f}%".format(num_ask / num_total * 100))
# Out:
# Ask Posts: 4.90%

# %%
print("Show Posts: {:.2f}%".format(num_show / num_total * 100))
# Out:
# Show Posts: 2.40%

# %%
print("Other Posts: {:.2f}%".format(num_other / num_total * 100))
# Out:
# Other Posts: 92.69%

# %% [markdown]
# ### Conclusion
# _The percentage of comments of 'Ask Posts:' is larger than the percentage of comments for 'Show Posts:'. This demonstrates that users will engage better when questions are asked of others rather than users showing what they have done, although the total number of comments from both sets of posts is still less than 8%._
